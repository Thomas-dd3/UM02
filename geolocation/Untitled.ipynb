# %%
import pandas as pd

# %%
df = pd.read_csv("ShanghaiPOI2017-clean.csv")

# %%
df.head()
# Out:
#    Unnamed: 0   ID        GPSX       GPSY    GBCODE
# 0           0  1.0  121.296368  31.188324  990000.0
# 1           1  1.0  121.473360  31.228923  990000.0
# 2           2  1.0  121.399378  31.205028  990000.0
# 3           3  1.0  121.529628  31.271063  990000.0
# 4           4  2.0  121.169185  31.282332  990000.0

# %%
df.GBCODE.value_counts()
# Out:
# 230100.0    256018
# 110100.0    114423
# 139900.0     90100
# 219900.0     81016
# 240303.0     78537
#              ...
# 210500.0         1
# 240000.0         1
# 160100.0         1
# 190103.0         1
# 220300.0         1
# Name: GBCODE, Length: 322, dtype: int64

# %%
df_metro = df[df['GBCODE']==200401]

# %%
df_metro = df_metro.rename(columns={"GPSX": "longitude", "GPSY": "latitude"})
# Out:
# C:\Users\Roger\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Roger\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#        Unnamed: 0    ID    GBCODE   longitude   latitude
# 70929       70929  45.0  200401.0  121.402566  31.252593
# 70930       70930  45.0  200401.0  121.385318  31.270841
# 70931       70931  45.0  200401.0  121.371397  31.273481
# ...

# %%
df_metro.to_csv("Shanghai-metro.csv")
