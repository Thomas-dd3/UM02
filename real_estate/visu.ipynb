# %%
import pandas as pd

# %%
# Matplotlib for additional customization
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# Seaborn for plotting and styling
import seaborn as sns

# %%
df = pd.read_csv('UTSEUS-anjuke-real-estate.csv')

# %%
df.head()

# %%
# here you get .50 % of the rows 
df_half = df.sample(frac = 0.5)

# %%
print(df.size)
print(df_half.size)
# Out:
# 6071377
# 3035682

# %%
sns.set()

# %%
sns.lmplot(x='longitude', y='latitude', data=df)

# %%
sns.lmplot(x='surface', y='price', data=df)
plt.xscale('log')
plt.yscale('log')

# %%
sns.lmplot(x='surface', y='price', data=df,
           fit_reg=False, # No regression line
           hue='district')
plt.xscale('log')
plt.yscale('log')

# %%
plt.figure(figsize=(12,9))
df2 = df.drop(columns = ['price','onesquaremeter', 'surface', 'longitude', 'latitude', 'done'])
sns.boxplot(data=df2)

# %%
plt.figure(figsize=(12,9))
sns.boxplot(data=df['price'])

# %%
# Set theme
sns.set_style('whitegrid')
plt.figure(figsize=(20,12))
 
# Violin plot
sns.violinplot(x='district', y='onesquaremeter', data=df)
plt.yscale('log')

# %%
# Swarm plot with Pokemon color palette
sns.swarmplot(x='X', y='Y', data=df_half)

# %%
# Swarmplot with melted_df
sns.swarmplot(x='Stat', y='value', data=melted_df, 
              hue='Type 1')

# %%
plt.figure(figsize=(14,10))
# Density Plot
sns.kdeplot(df_half.longitude, df_half.latitude)
# Out:
# C:\Users\Roger\Anaconda3\lib\site-packages\matplotlib\contour.py:1520: UserWarning: Warning: converting a masked element to nan.
#   self.zmax = float(z.max())
# C:\Users\Roger\Anaconda3\lib\site-packages\matplotlib\contour.py:1521: UserWarning: Warning: converting a masked element to nan.
#   self.zmin = float(z.min())
# C:\Users\Roger\Anaconda3\lib\site-packages\matplotlib\contour.py:1169: RuntimeWarning: invalid value encountered in less
#   under = np.nonzero(lev < self.zmin)[0]
# C:\Users\Roger\Anaconda3\lib\site-packages\matplotlib\contour.py:1171: RuntimeWarning: invalid value encountered in greater
#   over = np.nonzero(lev > self.zmax)[0]
# C:\Users\Roger\Anaconda3\lib\site-packages\matplotlib\contour.py:1200: RuntimeWarning: invalid value encountered in greater
#   inside = (self.levels > self.zmin) & (self.levels < self.zmax)
# C:\Users\Roger\Anaconda3\lib\site-packages\matplotlib\contour.py:1200: RuntimeWarning: invalid value encountered in less
# ...
